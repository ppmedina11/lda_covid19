# %% [markdown]
# <div id="references" style="background-color:#80CDC6 ; padding: 10px 0;">
#     <center><h1 style="color:#342E5B; font-weight:bold">INSTANCES</h1></center>
# </div>

# %% [markdown]
# ![instances.png](attachment:800781ee-c73b-4120-9783-2ba777d4de76.png)
# <center><small><b>Figure 1.</b> Number of instances and instance types used for the project.</small></center>

# %% [markdown]
# <div id="references" style="background-color:#80CDC6 ; padding: 10px 0;">
#     <center><h1 style="color:#342E5B; font-weight:bold">TOTAL SIZE OF THE ACTUAL DATA</h1></center>
# </div>

# %% [markdown]
# **Note: The computation of the file size was done through Excel as the total sum was not being reflected through the AWS CLI (kindly refer to Figure 3). The CSV file of the computation is also attached along with this notebook.**

# %% [markdown]
# ![filesize_1.png](attachment:8a2c66a4-44a6-4ac5-b7f2-f315850157d9.png)
# <center><small><b>Figure 2.</b> Total size of the dataset used.</small></center>

# %% [markdown]
# ![filesize_2.png](attachment:06d1e274-f143-4125-b5cd-202aed5172e7.png)
# <center><small><b>Figure 3.</b> Total size of dataset not showing on AWS CLI.</small></center>
